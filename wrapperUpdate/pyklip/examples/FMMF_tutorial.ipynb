# %% [markdown]
# # Forward Model Matched Filter (FMMF) tutorial for GPI
#
# This is a first attempt at a FMMF tutorial. A FMMF has only been implemented for GPI yet.
#
# Refer to http://pyklip.readthedocs.io/en/latest/install.html#note-on-parallelized-performance for use of mkl.

# %%
# imports
try:
    import mkl
    mkl.set_num_threads(1)
except:
    print("/!\ Please Read http://pyklip.readthedocs.io/en/latest/install.html#note-on-parallelized-performance")
    
from pyklip.kpp.metrics.FMMF import FMMF

# %% [markdown]
# ## FMMF Quick start
#
# A wrapper object has been implemented in the context of kpop for the FMMF KLIP implementation.
#
# The KLIP POst Processing framework has been implemented with surveys application in mind. It includes several wrapper functions, which all ihnerit from the same object, and performing different tasks like matched filters, SNR map calculation, detection of high SNR blobs and others. A lot features have been automated and are therefore hidden from the user, which is appreciable when running the same sequence of tasks and many datasets. The downside is that it doesn't give the user as much flexibility.

# %% [markdown]
# ### Defining FMMF Object

# %%
FMMFObj = FMMF(filename = "S*distorcorr.fits",
                PSF_cube_filename = None,
                mute=None,
                N_threads=None,
                predefined_sectors = "smallSep",
                label = "FMMF_test",
                overwrite=True,
                numbasis=[10],
                maxnumbasis = 50,
                mvt=1.0)

# %% [markdown]
# ### Run FMMF
# FMMF is meant to be ran on 16 (or above) cores machine with 60GB (or above) of RAM. Even with such computers, the code will take many hours to days to run on a normal dataset. Therefore, an iPython notebook is not an optimal mean to run this code. One should consider running a script with the linux command *nice* to let it run in the background. The ideal environment for this FMMF implementation is a supercluster where several dataset can be ran in parallel.

# %%
inputDir = "../tests/data/"
outputDir = inputDir

FMMFObj.initialize(inputDir=inputDir,
                   outputDir=outputDir,
                   spectrum = "t1800g100nc",
                   compact_date="myDataDate")
FMMFObj.calculate()
FMMFObj.save()
# Out:
# ~~ INITializing FMMF ~~
# Opened: /home/sda/jruffio/pyklip/tests/data/S20131210S0111_spdc_distorcorr.fits
# The star spectral type is: A6V
# Using default filename for PSF cube: *-original_PSF_cube.fits
# Loading PSF cube: /home/sda/jruffio/pyklip/tests/data/Beta_Pic_myDataDate_J-original_PSF_cube.fits
# Reading File: /home/sda/jruffio/pyklip/tests/data/S20131210S0092_spdc_distorcorr.fits
# /home/anaconda/lib/python2.7/site-packages/scipy/interpolate/fitpack2.py:1099: UserWarning:
# The coefficients of the spline returned have been computed as the
# minimal norm least-squares solution of a (numerically) rank deficient
# system (deficiency=129). If deficiency is large, the results may be
# inaccurate. Deficiency may strongly depend on the value of eps.
#   warnings.warn(message)
# Reading File: /home/sda/jruffio/pyklip/tests/data/S20131210S0099_spdc_distorcorr.fits
# Reading File: /home/sda/jruffio/pyklip/tests/data/S20131210S0111_spdc_distorcorr.fits
# Begin align and scale images for each wavelength
# Align and scale finished
# Starting KLIP for sector 1/54
# Time spent on last sector: 0s
# Time spent since beginning: 0s
# First sector: Can't predict remaining time
#  100.00% of sector, 1.85% of total completed
# Starting KLIP for sector 2/54
# Time spent on last sector: 14s
# Time spent since beginning: 14s
# Estimated remaining time: 729s
#  100.00% of sector, 3.70% of total completed
# Starting KLIP for sector 3/54
# Time spent on last sector: 14s
# Time spent since beginning: 27s
# Estimated remaining time: 711s
#  100.00% of sector, 5.56% of total completed
# Starting KLIP for sector 4/54
# Time spent on last sector: 14s
# Time spent since beginning: 41s
# Estimated remaining time: 705s
#  100.00% of sector, 7.41% of total completed
# Starting KLIP for sector 5/54
# Time spent on last sector: 13s
# Time spent since beginning: 55s
# Estimated remaining time: 685s
#  100.00% of sector, 9.26% of total completed
# Starting KLIP for sector 6/54
# Time spent on last sector: 14s
# Time spent since beginning: 69s
# Estimated remaining time: 676s
#  100.00% of sector, 11.11% of total completed
# Starting KLIP for sector 7/54
# Time spent on last sector: 14s
# Time spent since beginning: 83s
# Estimated remaining time: 663s
#  100.00% of sector, 12.96% of total completed
# Starting KLIP for sector 8/54
# Time spent on last sector: 14s
# Time spent since beginning: 97s
# Estimated remaining time: 649s
#  100.00% of sector, 14.81% of total completed
# Starting KLIP for sector 9/54
# Time spent on last sector: 15s
# Time spent since beginning: 112s
# Estimated remaining time: 642s
#  100.00% of sector, 16.67% of total completed
# Starting KLIP for sector 10/54
# Time spent on last sector: 14s
# Time spent since beginning: 126s
# Estimated remaining time: 631s
#  100.00% of sector, 18.52% of total completed
# Starting KLIP for sector 11/54
# Time spent on last sector: 15s
# Time spent since beginning: 141s
# Estimated remaining time: 619s
#  100.00% of sector, 20.37% of total completed
# Starting KLIP for sector 12/54
# Time spent on last sector: 14s
# Time spent since beginning: 154s
# Estimated remaining time: 603s
#  100.00% of sector, 22.22% of total completed
# Starting KLIP for sector 13/54
# Time spent on last sector: 14s
# Time spent since beginning: 168s
# Estimated remaining time: 589s
#  100.00% of sector, 24.07% of total completed
# Starting KLIP for sector 14/54
# Time spent on last sector: 14s
# Time spent since beginning: 183s
# Estimated remaining time: 576s
#  100.00% of sector, 25.93% of total completed
# Starting KLIP for sector 15/54
# Time spent on last sector: 13s
# Time spent since beginning: 196s
# Estimated remaining time: 560s
#  100.00% of sector, 27.78% of total completed
# Starting KLIP for sector 16/54
# Time spent on last sector: 14s
# Time spent since beginning: 210s
# Estimated remaining time: 545s
#  100.00% of sector, 29.63% of total completed
# Starting KLIP for sector 17/54
# Time spent on last sector: 13s
# Time spent since beginning: 223s
# Estimated remaining time: 530s
#  100.00% of sector, 31.48% of total completed
# Starting KLIP for sector 18/54
# Time spent on last sector: 14s
# Time spent since beginning: 237s
# Estimated remaining time: 516s
#  100.00% of sector, 33.33% of total completed
# Starting KLIP for sector 19/54
# Time spent on last sector: 14s
# Time spent since beginning: 251s
# Estimated remaining time: 503s
#  100.00% of sector, 35.19% of total completed
# Starting KLIP for sector 20/54
# Time spent on last sector: 13s
# Time spent since beginning: 264s
# Estimated remaining time: 487s
#  100.00% of sector, 37.04% of total completed
# Starting KLIP for sector 21/54
# Time spent on last sector: 13s
# Time spent since beginning: 278s
# Estimated remaining time: 472s
#  100.00% of sector, 38.89% of total completed
# Starting KLIP for sector 22/54
# Time spent on last sector: 14s
# Time spent since beginning: 292s
# Estimated remaining time: 459s
#  100.00% of sector, 40.74% of total completed
# Starting KLIP for sector 23/54
# Time spent on last sector: 14s
# Time spent since beginning: 306s
# Estimated remaining time: 444s
#  100.00% of sector, 42.59% of total completed
# Starting KLIP for sector 24/54
# Time spent on last sector: 13s
# Time spent since beginning: 319s
# Estimated remaining time: 430s
#  100.00% of sector, 44.44% of total completed
# Starting KLIP for sector 25/54
# Time spent on last sector: 14s
# Time spent since beginning: 333s
# Estimated remaining time: 416s
#  100.00% of sector, 46.30% of total completed
# Starting KLIP for sector 26/54
# Time spent on last sector: 14s
# Time spent since beginning: 347s
# Estimated remaining time: 403s
#  100.00% of sector, 48.15% of total completed
# Starting KLIP for sector 27/54
# Time spent on last sector: 13s
# Time spent since beginning: 361s
# Estimated remaining time: 388s
#  100.00% of sector, 50.00% of total completed
# Starting KLIP for sector 28/54
# Time spent on last sector: 14s
# Time spent since beginning: 374s
# Estimated remaining time: 374s
#  100.00% of sector, 51.85% of total completed
# Starting KLIP for sector 29/54
# Time spent on last sector: 14s
# Time spent since beginning: 388s
# Estimated remaining time: 361s
#  100.00% of sector, 53.70% of total completed
# Starting KLIP for sector 30/54
# Time spent on last sector: 14s
# Time spent since beginning: 403s
# Estimated remaining time: 347s
#  100.00% of sector, 55.56% of total completed
# Starting KLIP for sector 31/54
# Time spent on last sector: 14s
# Time spent since beginning: 417s
# Estimated remaining time: 333s
#  100.00% of sector, 57.41% of total completed
# Starting KLIP for sector 32/54
# Time spent on last sector: 14s
# Time spent since beginning: 430s
# Estimated remaining time: 319s
#  100.00% of sector, 59.26% of total completed
# Starting KLIP for sector 33/54
# Time spent on last sector: 14s
# Time spent since beginning: 444s
# Estimated remaining time: 305s
#  100.00% of sector, 61.11% of total completed
# Starting KLIP for sector 34/54
# Time spent on last sector: 14s
# Time spent since beginning: 458s
# Estimated remaining time: 291s
#  100.00% of sector, 62.96% of total completed
# Starting KLIP for sector 35/54
# Time spent on last sector: 14s
# Time spent since beginning: 472s
# Estimated remaining time: 278s
#  100.00% of sector, 64.81% of total completed
# Starting KLIP for sector 36/54
# Time spent on last sector: 14s
# Time spent since beginning: 485s
# Estimated remaining time: 264s
#  100.00% of sector, 66.67% of total completed
# Starting KLIP for sector 37/54
# Time spent on last sector: 14s
# Time spent since beginning: 499s
# Estimated remaining time: 249s
#  100.00% of sector, 68.52% of total completed
# Starting KLIP for sector 38/54
# Time spent on last sector: 14s
# Time spent since beginning: 513s
# Estimated remaining time: 236s
#  100.00% of sector, 70.37% of total completed
# Starting KLIP for sector 39/54
# Time spent on last sector: 14s
# Time spent since beginning: 527s
# Estimated remaining time: 222s
#  100.00% of sector, 72.22% of total completed
# Starting KLIP for sector 40/54
# Time spent on last sector: 14s
# Time spent since beginning: 541s
# Estimated remaining time: 208s
#  100.00% of sector, 74.07% of total completed
# Starting KLIP for sector 41/54
# Time spent on last sector: 14s
# Time spent since beginning: 555s
# Estimated remaining time: 194s
#  100.00% of sector, 75.93% of total completed
# Starting KLIP for sector 42/54
# Time spent on last sector: 14s
# Time spent since beginning: 569s
# Estimated remaining time: 180s
#  100.00% of sector, 77.78% of total completed
# Starting KLIP for sector 43/54
# Time spent on last sector: 14s
# Time spent since beginning: 583s
# Estimated remaining time: 167s
#  100.00% of sector, 79.63% of total completed
# Starting KLIP for sector 44/54
# Time spent on last sector: 14s
# Time spent since beginning: 597s
# Estimated remaining time: 153s
#  100.00% of sector, 81.48% of total completed
# Starting KLIP for sector 45/54
# Time spent on last sector: 14s
# Time spent since beginning: 611s
# Estimated remaining time: 139s
#  100.00% of sector, 83.33% of total completed
# Starting KLIP for sector 46/54
# Time spent on last sector: 14s
# Time spent since beginning: 624s
# Estimated remaining time: 125s
#  100.00% of sector, 85.19% of total completed
# Starting KLIP for sector 47/54
# Time spent on last sector: 13s
# Time spent since beginning: 638s
# Estimated remaining time: 111s
#  100.00% of sector, 87.04% of total completed
# Starting KLIP for sector 48/54
# Time spent on last sector: 14s
# Time spent since beginning: 651s
# Estimated remaining time: 97s
#  100.00% of sector, 88.89% of total completed
# Starting KLIP for sector 49/54
# Time spent on last sector: 13s
# Time spent since beginning: 664s
# Estimated remaining time: 83s
#  100.00% of sector, 90.74% of total completed
# Starting KLIP for sector 50/54
# Time spent on last sector: 13s
# Time spent since beginning: 677s
# Estimated remaining time: 69s
#  100.00% of sector, 92.59% of total completed
# Starting KLIP for sector 51/54
# Time spent on last sector: 13s
# Time spent since beginning: 691s
# Estimated remaining time: 55s
#  100.00% of sector, 94.44% of total completed
# Starting KLIP for sector 52/54
# Time spent on last sector: 13s
# Time spent since beginning: 704s
# Estimated remaining time: 41s
#  100.00% of sector, 96.30% of total completed
# Starting KLIP for sector 53/54
# Time spent on last sector: 13s
# Time spent since beginning: 717s
# Estimated remaining time: 28s
#  100.00% of sector, 98.15% of total completed
# Starting KLIP for sector 54/54
# Time spent on last sector: 14s
# Time spent since beginning: 731s
# Estimated remaining time: 14s
#  100.00% of sector, 100.00% of total completed
# Closing threadpool

# %% [markdown]
# ## Advanced Features

# %% [markdown]
# **This section is in progress.**
#
# Most of them are automatically treated by the FMMF object but one could want to take a closer look:
# Sectors Definition, spectrum, Overlap, PSF cube, spectral type of the target, fakes management, noFM
#
# Also all kppPerDir related features when reducing campaign data.
