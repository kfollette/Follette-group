# %% [markdown]
# ## Figuring out how to plot the MinMs targets in 3D

# %%
#Importing some modules to help out with the plotting 
from mpl_toolkits import mplot3d #This contains a lot of the 3D stuff that we can play around with 
# %matplotlib notebook

#Standard imports below 
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
fig = plt.figure() #Creating the figure 
ax = plt.axes(projection='3d') #This plots the axes that we see below. The projection = 3d is important as it 
#tells python to plot the axes in 3D space
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#Importing the data from the excel sheets and into arrays 
new_data = pd.read_csv('MinMs_Sample_Properties - Gaia Properties.csv', delimiter = '\t')
old_data = pd.read_csv('MinMs_Sample_Properties - MinMs_old.csv', delimiter = '\t')

# %%
new_data.head()
# Out:
#         Name      _r    _RAJ2000   _DEJ2000     RA_ICRS  e_RA_ICRS    DE_ICRS  \
# 0  HIP113296  16.633  344.145020  16.553432  344.140372     0.0344  16.552209
# 1   HIP29052   4.254   91.932234 -25.744862   91.931351     0.0191 -25.745736
# 2   HIP28035   4.881   88.930060 -26.856503   88.931579     0.0215 -26.856544
# 3   HIP36985   4.618  114.029499  -3.110775  114.029794     0.1967  -3.112024
# 4  HIP117828   6.989  358.458804 -75.632533  358.463037     0.0261 -75.634166
#
#    e_DE_ICRS        Source       Plx    ...     e_RPmag   BP-RP       RV  \
# 0     0.0300  2.830000e+18  145.6107    ...       0.003  2.1553   -27.99
# 1     0.0257  2.910000e+18   87.6726    ...       0.001  2.5593
# 2     0.0270  2.910000e+18   71.2290    ...      0.0012   2.401
# 3     0.1236  3.060000e+18   71.0791    ...      0.0045  2.0393   -17.19
# 4     0.0227  6.380000e+18   98.8631    ...      0.0023   2.352    -9.63
#
#     e_RV     Teff       AG  E(BP-RP)     Rad  Lum       Ref
# ...

# %%
ax = plt.axes(projection='3d')

#plot?

lon = new_data['_RAJ2000']
lat = new_data['_DEJ2000']
radius = new_data['Distance']

ax.plot(lon, lat, radius, '.')
ax.set_xlabel('RA (ICRS)')
ax.set_ylabel('Dec (ICRS)')
ax.set_zlabel('Radius?')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 0, 'Radius?')

# %%
old_data.head()
# Out:
#    Full   HIP  RAJ2000  deg  DEJ2000  deg  pmRA  mas/yr  pmDE  mas/yr  \
# 0     1   428      1.295368     45.786567         869.7        -151.0
# 1     2   439      1.351784    -37.357361        5634.4       -2336.4
# 2     3  1242      3.873033    -16.133639         -32.1        -149.7
# 3     4  1475      4.595353     44.022949        2887.5         408.9
# 4     5  2552      8.122664     67.235616        1741.1        -246.8
#
#    Vmag  mag  Jmag  mag  e_  mag  Hmag  mag   ...    e_  mag.2  plx  mas  \
# 0       9.95      6.704    0.021      6.098   ...        0.018     88.88
# 1       8.56      5.328    0.019      4.828   ...        0.017    230.42
# 2      11.49      7.215    0.019      6.712   ...        0.016    200.53
# 3       8.09      5.252    0.264      4.476   ...        0.020    278.76
# 4      10.27      6.844    0.023      6.268   ...        0.023     99.35
#
#    e_  mas  Dist  pc  e_  pc  SpType   r_ [Fe/H]  [-] r_.1  Simbad
# ...

# %%
ax = plt.axes(projection='3d')

#plot?

lon = old_data['RAJ2000  deg']
lat = old_data['DEJ2000  deg']
radius = old_data['Dist  pc']

ax.plot(lon, lat, radius, '.')
ax.set_xlabel('RA (ICRS)')
ax.set_ylabel('Dec (ICRS)')
ax.set_zlabel('Radius?')
plt.savefig('Old Data.png')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#Trying to see if its possible to make a boundary at 15pc...
num_pts = 100
indices = np.arange(0, num_pts, dtype=float)

phi = np.arccos(1 - 2*indices/num_pts)
theta = np.pi * (1 + 5**0.5) * indices

x, y, z = np.cos(theta) * np.sin(phi), np.sin(theta) * np.sin(phi), np.cos(phi);

plt.figure().add_subplot(111,projection='3d').scatter(x, y, z);
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
